# %%
import pandas as pd

# %%
df=pd.read_csv("")

# %%
category_mapping={'Fiction':"Fiction"}

# %%
from transformers import Pipeline
fiction_categories=['Fiction','Nonfiction']
pipe=Pipeline("zero-shot-classification",model="facebook/bart-large-mnli")

# %%
sequence=

# %%
pipe(sequence,fiction_categories)

# %%
def generate_predictions(sequence,categories):
    predictions=pipe(sequence,categories)
    max_index=np.argmax(pipe(sequence,fiction_categories)["scores"])
    min_index=pipe(sequence,fiction_categories)["labels"][max_index]
    max_label=predictions["label"][max_index]
    return max_label

# %%
from tqdm import tqdm
actual_cats=[]
predicted_cats=[]
for i in tqdm(range(0,300)):
    sequence=books.loc[books["simple_categories"]=="Fiction","description"].reset_index(dropna=True)
    predicted_cats+=[generate_predictions(sequence,fiction_categories)]
    actual_cats+=["Fiction"]

# %%
for i in tqdm(range(0,300)):
    sequence=books.loc[books["simple_categories"]=="Fiction","description"].reset_index(dropna=True)
    predicted_cats+=[generate_predictions(sequence,fiction_categories)]
    actual_cats+=["NonFiction"]

# %%
predictions_df["corrected_prediction"]=(np.where(prediction_df["actual_categories"],1,0))

# %%
predicted_df["correct_prediction"].sum()/len(predicted_df)

# %%
isbns=[]
predicted_cats=[]
missing_cats=books.loc[books["simple_categories"].isna(),["isbn13","description"]].reset_index(dropna=True)

# %%
for i  in tqdm(range(0,len(missing_cats))):
    sequence=missing_cats["description"]
    predicted_cats+=[generate_predictions(sequence,fiction_categories)]
    isbns+=[missing_cats["isbn13"][i]]

# %%
missing_predicted_df=

# %%
books=pd.merge(books,missing_predicted_df,on="isbn13",how="left")
books["simple_categories"]=np.where(books["simple_categories"].isna(),books["predicted_categories"],books["simple_categories"])
books=books.drop(columns=["predicted_categories"])

# %%
books[books["categories"].str.lower().isin(["romance","science fiction","scifi","comedy","crime","historical"])]

# %%
## sentimental analysis

# %%
import pandas as pd
books=pd.read_csv("BooksDataset.csv")

# %%
# !pip3 install transformers
# Out:
# ...
#   Using cached filelock-3.20.0-py3-none-any.whl.metadata (2.1 kB)
# ...
#   Using cached pyyaml-6.0.3-cp311-cp311-win_amd64.whl.metadata (2.4 kB)
# ...
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ...
#   Using cached fsspec-2025.9.0-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached certifi-2025.10.5-py3-none-any.whl.metadata (2.5 kB)
# ...
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    ------------- -------------------------- 3.9/12.0 MB 21.3 MB/s eta 0:00:01
#    ---------------------------------------  11.8/12.0 MB 30.8 MB/s eta 0:00:01
#    ---------------------------------------- 12.0/12.0 MB 27.8 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 566.1/566.1 kB 9.8 MB/s  0:00:00
# ...

# %%
books.columns
# Out:
# Index(['Title', 'Authors', 'Description', 'Category', 'Publisher',
#        'Publish Date', 'Price'],
#       dtype='object')

# %%
books["Description"][0]
# Out:
# nan

# %%
from transformers import pipeline
classifier=pipeline("text-classification",model="j-hatmann/emotion-english-distilroberta-base",return_all_scores=True)
classifier("I love this")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from transformers import pipeline
#       2 classifier=pipeline("text-classification",model="j-hatmann/emotion-english-distilroberta-base",return_all_scores=True)
#       3 classifier("I love this")
#
# ModuleNotFoundError: No module named 'transformers'

# %%
classifier(books["Description"][0])

# %%
classifier(books["Description"][0].split('.'))

# %%
sentences=books["Description"][0].split(".")
predictions=classifier(sentences)
sentences[0]
predictions[0]

# %%
import numpy as np
emotions_labels=["anger","disgust","fear","joy","sadness","surpise","neutral"]
isbn=[]
emotion_scores={label:[] for label in emotions_labels}

def calcuate_max_emotion_scores(predictions):
    for prediciton in predictions:
        sorted_prediction=sorted(prediction,key=lambda x:x["label"])
        for index,label in enumerate(emotions_labels):
            per_emotion_score[label].append(sorted_prediction)
    per_emotion_score[label].append(sorted_predictions[index]["score"])
    return {label:np.max(scores) for label,score in per_emotion_scores.items()}

# %%
for i in range(10):
    isbn.append(books["isbn13"][i])
    sentences=books["description"][i].split(".")
    predictions=classifier(sentences)
    max_scores=calcuate_max_emotion_scores(predictions)
    for label in emotions_labels:
        emotion_scores[label].append(max_scores[label])
